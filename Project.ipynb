# %% [markdown]
# Question1: What is the correlation between features in the dataset. and what two features have very strong correlation with the independent variable? Justify with reason
#
# Question2: Which feature has more outliers. Explain with a visualization.
#
# Question3: In which Age group Majority of people have diabetes? Make a visualization to validate your finding.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
# 1. ...correlation b/w features....
df.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.129459  ...  0.544341  0.221898
# Glucose                      0.129459  1.000000  ...  0.263514  0.466581
# BloodPressure                0.141282  0.152590  ...  0.239528  0.065068
# SkinThickness               -0.081672  0.057328  ... -0.113970  0.074752
# Insulin                     -0.073535  0.331357  ... -0.042163  0.130548
# BMI                          0.017683  0.221071  ...  0.036242  0.292695
# DiabetesPedigreeFunction    -0.033523  0.137337  ...  0.033561  0.173844
# Age                          0.544341  0.263514  ...  1.000000  0.238356
# Outcome                      0.221898  0.466581  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# ANSWER 1:
# There are 8 independant variables, so the question is wrong.....
# But what we can answer is which two features have strong correlation with dependant variable, i.e Outcome.
# As observed in corr. matrix or heatmap, GLUCOSE followed BMI have the most and 2nd most high correlation with Outcome.

# %%
sns.heatmap(df.corr(), annot=True)

# %%
for i in df.columns:
  plt.title(i)
  plt.boxplot(df[i],vert=True)
  plt.show()

# %% [markdown]
# ANSWER 2: As u see in the above visualizations, the feature with the most outliers should be: Insulin, follwed by DiabitiesPedigreeIndex, then BMI, then Age, then Blood Pressure.

# %%
sns.histplot(data=df, x='Age',hue='Outcome')
plt.show()

# %% [markdown]
# ANSWER 3: As u see, the group with max. diabities case is: 20-30 yrs.
